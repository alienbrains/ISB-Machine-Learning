# %% [markdown]
# # **Unzipping the Dataset**

# %%
import zipfile as z
zip_ref = z.ZipFile("/content/train.csv.zip", "r") #the source path is given
zip_ref.extractall("/content/") #the destination part is given

zip_ref.close()

# %% [markdown]
# # **Importing important libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_csv("/content/train.csv")
df
# Out:
#       Id   Open Date        City  City Group  ... P35  P36  P37    revenue
# 0      0  07/17/1999    İstanbul  Big Cities  ...   4    3    4  5653753.0
# 1      1  02/14/2008      Ankara  Big Cities  ...   0    0    0  6923131.0
# 2      2  03/09/2013  Diyarbakır       Other  ...   0    0    0  2055379.0
# 3      3  02/02/2012       Tokat       Other  ...  12   12    6  2675511.0
# 4      4  05/09/2009   Gaziantep       Other  ...   4    3    3  4316715.0
# ..   ...         ...         ...         ...  ...  ..  ...  ...        ...
# 132  132  06/25/2008     Trabzon       Other  ...   0    0    0  5787594.0
# 133  133  10/12/2006       İzmir  Big Cities  ...   0    0    0  9262754.0
# 134  134  07/08/2006     Kayseri       Other  ...   0    0    0  2544857.0
# 135  135  10/29/2010    İstanbul  Big Cities  ...   0    0    0  7217634.0
# 136  136  09/01/2009    İstanbul  Big Cities  ...   0    0    0  6363241.0
#
# [137 rows x 43 columns]

# %% [markdown]
# # **Data Analysis & Data Visualization**

# %%
df.shape
# Out:
# (137, 43)

# %% [markdown]
# This says that the dataset has 137 rows and 43 columns. Sumply meaning, there are 137 data points in the datatset and there are 43 features, one of them is target feature.

# %%
df.columns
# Out:
# Index(['Id', 'Open Date', 'City', 'City Group', 'Type', 'P1', 'P2', 'P3', 'P4',
#        'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15',
#        'P16', 'P17', 'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25',
#        'P26', 'P27', 'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35',
#        'P36', 'P37', 'revenue'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Id            0
# Open Date     0
# City          0
# City Group    0
# Type          0
# P1            0
# P2            0
# P3            0
# P4            0
# P5            0
# P6            0
# P7            0
# P8            0
# P9            0
# P10           0
# P11           0
# P12           0
# P13           0
# P14           0
# P15           0
# P16           0
# P17           0
# P18           0
# P19           0
# P20           0
# P21           0
# P22           0
# P23           0
# P24           0
# P25           0
# P26           0
# P27           0
# P28           0
# P29           0
# P30           0
# P31           0
# P32           0
# P33           0
# P34           0
# P35           0
# P36           0
# P37           0
# revenue       0
# dtype: int64

# %% [markdown]
# This says there are no Missing Values. Good for us.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 43 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          137 non-null    int64
#  1   Open Date   137 non-null    object
#  2   City        137 non-null    object
#  3   City Group  137 non-null    object
#  4   Type        137 non-null    object
#  5   P1          137 non-null    int64
#  6   P2          137 non-null    float64
#  7   P3          137 non-null    float64
#  8   P4          137 non-null    float64
#  9   P5          137 non-null    int64
#  10  P6          137 non-null    int64
#  11  P7          137 non-null    int64
#  12  P8          137 non-null    int64
#  13  P9          137 non-null    int64
#  14  P10         137 non-null    int64
#  15  P11         137 non-null    int64
#  16  P12         137 non-null    int64
#  17  P13         137 non-null    float64
#  18  P14         137 non-null    int64
#  19  P15         137 non-null    int64
#  20  P16         137 non-null    int64
#  21  P17         137 non-null    int64
#  22  P18         137 non-null    int64
#  23  P19         137 non-null    int64
#  24  P20         137 non-null    int64
#  25  P21         137 non-null    int64
#  26  P22         137 non-null    int64
#  27  P23         137 non-null    int64
#  28  P24         137 non-null    int64
#  29  P25         137 non-null    int64
#  30  P26         137 non-null    float64
#  31  P27         137 non-null    float64
#  32  P28         137 non-null    float64
#  33  P29         137 non-null    float64
#  34  P30         137 non-null    int64
#  35  P31         137 non-null    int64
#  36  P32         137 non-null    int64
#  37  P33         137 non-null    int64
#  38  P34         137 non-null    int64
#  39  P35         137 non-null    int64
#  40  P36         137 non-null    int64
#  41  P37         137 non-null    int64
#  42  revenue     137 non-null    float64
# dtypes: float64(9), int64(30), object(4)
# memory usage: 46.1+ KB

# %% [markdown]
# From here we see that **4 of the features are object type** which the model can not understand. So they need to be **encoded**.
#
# Apart from that, Another observation is that we don't need to use the feature 'ID' as it's anyway **not going to give me any insight of the revenue**. So we will simply drop it.

# %%
#The ID column is irrelevant so we will drop them.
df=df.drop('Id',axis=1)
df
# Out:
#       Open Date        City  City Group Type  P1  ...  P34  P35  P36  P37    revenue
# 0    07/17/1999    İstanbul  Big Cities   IL   4  ...    5    4    3    4  5653753.0
# 1    02/14/2008      Ankara  Big Cities   FC   4  ...    0    0    0    0  6923131.0
# 2    03/09/2013  Diyarbakır       Other   IL   2  ...    0    0    0    0  2055379.0
# 3    02/02/2012       Tokat       Other   IL   6  ...   18   12   12    6  2675511.0
# 4    05/09/2009   Gaziantep       Other   IL   3  ...    3    4    3    3  4316715.0
# ..          ...         ...         ...  ...  ..  ...  ...  ...  ...  ...        ...
# 132  06/25/2008     Trabzon       Other   FC   2  ...    0    0    0    0  5787594.0
# 133  10/12/2006       İzmir  Big Cities   FC   4  ...    0    0    0    0  9262754.0
# 134  07/08/2006     Kayseri       Other   FC   3  ...    0    0    0    0  2544857.0
# 135  10/29/2010    İstanbul  Big Cities   FC   4  ...    0    0    0    0  7217634.0
# 136  09/01/2009    İstanbul  Big Cities   FC   4  ...    0    0    0    0  6363241.0
#
# [137 rows x 42 columns]

# %% [markdown]
# Now I am going to convert the 'Open Date' feature in **datetime format** so that I can extract the month and year from it. I want to do this because the date doesn't give me any insight of the revenue. But the **month and year surely does.**

# %%
df['Open Date'] = pd.to_datetime(df['Open Date'])
df
# Out:
#      Open Date        City  City Group Type  P1  ...  P34  P35  P36  P37    revenue
# 0   1999-07-17    İstanbul  Big Cities   IL   4  ...    5    4    3    4  5653753.0
# 1   2008-02-14      Ankara  Big Cities   FC   4  ...    0    0    0    0  6923131.0
# 2   2013-03-09  Diyarbakır       Other   IL   2  ...    0    0    0    0  2055379.0
# 3   2012-02-02       Tokat       Other   IL   6  ...   18   12   12    6  2675511.0
# 4   2009-05-09   Gaziantep       Other   IL   3  ...    3    4    3    3  4316715.0
# ..         ...         ...         ...  ...  ..  ...  ...  ...  ...  ...        ...
# 132 2008-06-25     Trabzon       Other   FC   2  ...    0    0    0    0  5787594.0
# 133 2006-10-12       İzmir  Big Cities   FC   4  ...    0    0    0    0  9262754.0
# 134 2006-07-08     Kayseri       Other   FC   3  ...    0    0    0    0  2544857.0
# 135 2010-10-29    İstanbul  Big Cities   FC   4  ...    0    0    0    0  7217634.0
# 136 2009-09-01    İstanbul  Big Cities   FC   4  ...    0    0    0    0  6363241.0
#
# [137 rows x 42 columns]

# %% [markdown]
# Here I am extracting the **month** from the feature **'Open Date'**.

# %%
df['month']=[x.month for x in df['Open Date']]

# %% [markdown]
# Here I am extracting the **year** from the feature **'Open Date'**.

# %%
df['year']=[x.year for x in df['Open Date']]

# %% [markdown]
# Now we will **drop 'Open Date'** as well as we have extracted all the information from it and now its of no use to me.

# %%
df=df.drop(['Open Date'],axis=1)
df
# Out:
#            City  City Group Type  P1   P2  ...  P36  P37    revenue  month  year
# 0      İstanbul  Big Cities   IL   4  5.0  ...    3    4  5653753.0      7  1999
# 1        Ankara  Big Cities   FC   4  5.0  ...    0    0  6923131.0      2  2008
# 2    Diyarbakır       Other   IL   2  4.0  ...    0    0  2055379.0      3  2013
# 3         Tokat       Other   IL   6  4.5  ...   12    6  2675511.0      2  2012
# 4     Gaziantep       Other   IL   3  4.0  ...    3    3  4316715.0      5  2009
# ..          ...         ...  ...  ..  ...  ...  ...  ...        ...    ...   ...
# 132     Trabzon       Other   FC   2  3.0  ...    0    0  5787594.0      6  2008
# 133       İzmir  Big Cities   FC   4  5.0  ...    0    0  9262754.0     10  2006
# 134     Kayseri       Other   FC   3  4.0  ...    0    0  2544857.0      7  2006
# 135    İstanbul  Big Cities   FC   4  5.0  ...    0    0  7217634.0     10  2010
# 136    İstanbul  Big Cities   FC   4  5.0  ...    0    0  6363241.0      9  2009
#
# [137 rows x 43 columns]

# %% [markdown]
# Now let's try to **visualize the trends** in month and year to understand how they affect the revenue.

# %%
sns.countplot(df['month'])

# %% [markdown]
# From the above plot we can look at the occurence of various months in the dataset. We have the most data for the last 5 months. The highest of them is from **August** and **December**. Now let's see in which month did we have the most revenue. For this I will try to find the **mean of the revenue** for each month.

# %%
df.groupby('month')['revenue'].mean()
# Out:
# month
# 1     5.900851e+06
# 2     4.189109e+06
# 3     3.969557e+06
# 4     4.726097e+06
# 5     3.657800e+06
# 6     3.776214e+06
# 7     3.458596e+06
# 8     3.883020e+06
# 9     5.390856e+06
# 10    5.236838e+06
# 11    4.721400e+06
# 12    4.299763e+06
# Name: revenue, dtype: float64

# %% [markdown]
# From here we can see that the month **January gave the most revenue** to the restraunts. **September** and **October** followed January. Let's try to plot a bargraph with the same and visualize the same trends.

# %%
sns.barplot('month','revenue',data=df)

# %% [markdown]
# So these bargraphs are giving out the same information. Now lets try to do same kind of stuffs for the newly generated feature **'year'**.

# %%
sns.countplot(df['year'])

# %% [markdown]
# Here we are having a bit of trouble in visualization because the labels in the x-axis are not clear. Let's try to zoom in a bit!!

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['year'])

# %% [markdown]
# From here we can see that the most of the data is from the years **2008-2013**. Out of them the most of the data is from the year 2011. The other years are contruibuting really less on the basis of number of data. This is also going to affect the results as well.

# %%
df.groupby('year')['revenue'].mean()
# Out:
# year
# 1996    3.903884e+06
# 1997    4.286645e+06
# 1998    4.251905e+06
# 1999    7.329030e+06
# 2000    1.359602e+07
# 2002    4.991022e+06
# 2004    3.482435e+06
# 2005    6.611118e+06
# 2006    4.203972e+06
# 2007    5.079333e+06
# 2008    4.876962e+06
# 2009    4.652457e+06
# 2010    4.383878e+06
# 2011    4.147879e+06
# 2012    3.837859e+06
# 2013    2.532287e+06
# 2014    2.464944e+06
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(15,6))
sns.barplot('year','revenue',data=df)

# %% [markdown]
# Out of all the years, the highest revenue was generated in the year **2000** and after that **1999** and **2005**.

# %% [markdown]
# # **Data Preprocessing.**

# %%
df['Type'].value_counts()
# Out:
# FC    76
# IL    60
# DT     1
# Name: Type, dtype: int64

# %% [markdown]
# There are 3 distinct values in the feature **'Type'**. We can encode the values as this:
#
# **FC as 0;**
#
#
# **IL as 1;**
#
# **DT as 2;**
#
# The order or the numbers can be anything.

# %%
ty={'FC':0,'IL':1,'DT':2}
df['Type'] = df['Type'].map(ty)

# %%
df
# Out:
#            City  City Group  Type  P1   P2  ...  P36  P37    revenue  month  year
# 0      İstanbul  Big Cities     1   4  5.0  ...    3    4  5653753.0      7  1999
# 1        Ankara  Big Cities     0   4  5.0  ...    0    0  6923131.0      2  2008
# 2    Diyarbakır       Other     1   2  4.0  ...    0    0  2055379.0      3  2013
# 3         Tokat       Other     1   6  4.5  ...   12    6  2675511.0      2  2012
# 4     Gaziantep       Other     1   3  4.0  ...    3    3  4316715.0      5  2009
# ..          ...         ...   ...  ..  ...  ...  ...  ...        ...    ...   ...
# 132     Trabzon       Other     0   2  3.0  ...    0    0  5787594.0      6  2008
# 133       İzmir  Big Cities     0   4  5.0  ...    0    0  9262754.0     10  2006
# 134     Kayseri       Other     0   3  4.0  ...    0    0  2544857.0      7  2006
# 135    İstanbul  Big Cities     0   4  5.0  ...    0    0  7217634.0     10  2010
# 136    İstanbul  Big Cities     0   4  5.0  ...    0    0  6363241.0      9  2009
#
# [137 rows x 43 columns]

# %%
df['City Group'].value_counts()
# Out:
# Big Cities    78
# Other         59
# Name: City Group, dtype: int64

# %%
cg={'Big Cities':0,'Other':1}
df['City Group'] = df['City Group'].map(cg)

# %%
df
# Out:
#            City  City Group  Type  P1   P2  ...  P36  P37    revenue  month  year
# 0      İstanbul           0     1   4  5.0  ...    3    4  5653753.0      7  1999
# 1        Ankara           0     0   4  5.0  ...    0    0  6923131.0      2  2008
# 2    Diyarbakır           1     1   2  4.0  ...    0    0  2055379.0      3  2013
# 3         Tokat           1     1   6  4.5  ...   12    6  2675511.0      2  2012
# 4     Gaziantep           1     1   3  4.0  ...    3    3  4316715.0      5  2009
# ..          ...         ...   ...  ..  ...  ...  ...  ...        ...    ...   ...
# 132     Trabzon           1     0   2  3.0  ...    0    0  5787594.0      6  2008
# 133       İzmir           0     0   4  5.0  ...    0    0  9262754.0     10  2006
# 134     Kayseri           1     0   3  4.0  ...    0    0  2544857.0      7  2006
# 135    İstanbul           0     0   4  5.0  ...    0    0  7217634.0     10  2010
# 136    İstanbul           0     0   4  5.0  ...    0    0  6363241.0      9  2009
#
# [137 rows x 43 columns]

# %%
a=df['City'].value_counts()

# %% [markdown]
# Here manually creating the dictionary is inefficient. So we will store the city names in a list and then use the element as the **key** of the dictionary and the index of each element as its **key values**.

# %%
b=a.index

# %%
c={}
for i,j in enumerate(b):
  c.update({j:i})
  print(c)
# Out:
# {'İstanbul': 0}
# {'İstanbul': 0, 'Ankara': 1}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23, 'Şanlıurfa': 24}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23, 'Şanlıurfa': 24, 'Kütahya': 25}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23, 'Şanlıurfa': 24, 'Kütahya': 25, 'Elazığ': 26}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23, 'Şanlıurfa': 24, 'Kütahya': 25, 'Elazığ': 26, 'Karabük': 27}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23, 'Şanlıurfa': 24, 'Kütahya': 25, 'Elazığ': 26, 'Karabük': 27, 'Tokat': 28}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23, 'Şanlıurfa': 24, 'Kütahya': 25, 'Elazığ': 26, 'Karabük': 27, 'Tokat': 28, 'Edirne': 29}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23, 'Şanlıurfa': 24, 'Kütahya': 25, 'Elazığ': 26, 'Karabük': 27, 'Tokat': 28, 'Edirne': 29, 'Denizli': 30}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23, 'Şanlıurfa': 24, 'Kütahya': 25, 'Elazığ': 26, 'Karabük': 27, 'Tokat': 28, 'Edirne': 29, 'Denizli': 30, 'Balıkesir': 31}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23, 'Şanlıurfa': 24, 'Kütahya': 25, 'Elazığ': 26, 'Karabük': 27, 'Tokat': 28, 'Edirne': 29, 'Denizli': 30, 'Balıkesir': 31, 'Afyonkarahisar': 32}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Antalya': 5, 'Sakarya': 6, 'Tekirdağ': 7, 'Diyarbakır': 8, 'Adana': 9, 'Kayseri': 10, 'Eskişehir': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Amasya': 16, 'Osmaniye': 17, 'Bolu': 18, 'Kırklareli': 19, 'Isparta': 20, 'Kocaeli': 21, 'Kastamonu': 22, 'Uşak': 23, 'Şanlıurfa': 24, 'Kütahya': 25, 'Elazığ': 26, 'Karabük': 27, 'Tokat': 28, 'Edirne': 29, 'Denizli': 30, 'Balıkesir': 31, 'Afyonkarahisar': 32, 'Gaziantep': 33}

# %%
c
# Out:
# {'Adana': 9,
#  'Afyonkarahisar': 32,
#  'Amasya': 16,
#  'Ankara': 1,
#  'Antalya': 5,
#  'Aydın': 14,
#  'Balıkesir': 31,
#  'Bolu': 18,
#  'Bursa': 4,
#  'Denizli': 30,
#  'Diyarbakır': 8,
#  'Edirne': 29,
#  'Elazığ': 26,
#  'Eskişehir': 11,
#  'Gaziantep': 33,
#  'Isparta': 20,
#  'Karabük': 27,
#  'Kastamonu': 22,
#  'Kayseri': 10,
#  'Kocaeli': 21,
#  'Konya': 13,
#  'Kütahya': 25,
#  'Kırklareli': 19,
#  'Muğla': 12,
#  'Osmaniye': 17,
#  'Sakarya': 6,
#  'Samsun': 3,
#  'Tekirdağ': 7,
#  'Tokat': 28,
#  'Trabzon': 15,
#  'Uşak': 23,
#  'İstanbul': 0,
#  'İzmir': 2,
#  'Şanlıurfa': 24}

# %%
df['City'] = df['City'].map(c)
df
# Out:
#      City  City Group  Type  P1   P2  ...  P36  P37    revenue  month  year
# 0       0           0     1   4  5.0  ...    3    4  5653753.0      7  1999
# 1       1           0     0   4  5.0  ...    0    0  6923131.0      2  2008
# 2       8           1     1   2  4.0  ...    0    0  2055379.0      3  2013
# 3      28           1     1   6  4.5  ...   12    6  2675511.0      2  2012
# 4      33           1     1   3  4.0  ...    3    3  4316715.0      5  2009
# ..    ...         ...   ...  ..  ...  ...  ...  ...        ...    ...   ...
# 132    15           1     0   2  3.0  ...    0    0  5787594.0      6  2008
# 133     2           0     0   4  5.0  ...    0    0  9262754.0     10  2006
# 134    10           1     0   3  4.0  ...    0    0  2544857.0      7  2006
# 135     0           0     0   4  5.0  ...    0    0  7217634.0     10  2010
# 136     0           0     0   4  5.0  ...    0    0  6363241.0      9  2009
#
# [137 rows x 43 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 43 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        137 non-null    int64
#  1   City Group  137 non-null    int64
#  2   Type        137 non-null    int64
#  3   P1          137 non-null    int64
#  4   P2          137 non-null    float64
#  5   P3          137 non-null    float64
#  6   P4          137 non-null    float64
#  7   P5          137 non-null    int64
#  8   P6          137 non-null    int64
#  9   P7          137 non-null    int64
#  10  P8          137 non-null    int64
#  11  P9          137 non-null    int64
#  12  P10         137 non-null    int64
#  13  P11         137 non-null    int64
#  14  P12         137 non-null    int64
#  15  P13         137 non-null    float64
#  16  P14         137 non-null    int64
#  17  P15         137 non-null    int64
#  18  P16         137 non-null    int64
#  19  P17         137 non-null    int64
#  20  P18         137 non-null    int64
#  21  P19         137 non-null    int64
#  22  P20         137 non-null    int64
#  23  P21         137 non-null    int64
#  24  P22         137 non-null    int64
#  25  P23         137 non-null    int64
#  26  P24         137 non-null    int64
#  27  P25         137 non-null    int64
#  28  P26         137 non-null    float64
#  29  P27         137 non-null    float64
#  30  P28         137 non-null    float64
#  31  P29         137 non-null    float64
#  32  P30         137 non-null    int64
#  33  P31         137 non-null    int64
#  34  P32         137 non-null    int64
#  35  P33         137 non-null    int64
#  36  P34         137 non-null    int64
#  37  P35         137 non-null    int64
#  38  P36         137 non-null    int64
#  39  P37         137 non-null    int64
#  40  revenue     137 non-null    float64
#  41  month       137 non-null    int64
#  42  year        137 non-null    int64
# dtypes: float64(9), int64(34)
# memory usage: 46.1 KB

# %% [markdown]
# Now everything looks just fine. So we can go ahead with the data and start model building.

# %% [markdown]
# # **Building the Model**

# %% [markdown]
# The first task will be to **split the dataset** into train set and test set.

# %%
from sklearn.model_selection import train_test_split
x=df.drop('revenue',axis=1)
y=df['revenue']
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.30)

# %% [markdown]
# Let's check the dimension of train and test set.

# %%
X_train.shape
# Out:
# (95, 42)

# %%
y_train.shape
# Out:
# (95,)

# %%
X_test.shape
# Out:
# (42, 42)

# %%
y_test.shape
# Out:
# (42,)

# %% [markdown]
# Before moving ahead, I am importing all the models from sklearn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

# %% [markdown]
# ## Linear Regression

# %%
lr = LinearRegression() #create the object of the model
lr=lr.fit(X_train,y_train)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
pred = lr.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the linear regressor is: "+str(s))
print("The MsE with the linear regressor is: "+str(s1))
print("The R2_Score with the linear regressor is: "+str(s2))
# Out:
# The MAE with the linear regressor is: 2760134.0949603417
# The MsE with the linear regressor is: 11689207973416.166
# The R2_Score with the linear regressor is: -1.9853665850206448

# %% [markdown]
# ## Decision Tree Regressor

# %%
dtr = DecisionTreeRegressor() #create the object of the model
dtr=dtr.fit(X_train,y_train)

# %%
pred = dtr.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the DT regressor is: "+str(s))
print("The MsE with the DT regressor is: "+str(s1))
print("The R2_Score with the DT regressor is: "+str(s2))
# Out:
# The MAE with the DT regressor is: 2155843.3571428573
# The MsE with the DT regressor is: 10443914973910.12
# The R2_Score with the DT regressor is: -1.6673248393574438

# %% [markdown]
# ## Random Forest Regressor

# %%
r = RandomForestRegressor() #create the object of the model
r=r.fit(X_train,y_train)

# %%
pred = r.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the RF regressor is: "+str(s))
print("The MsE with the RF regressor is: "+str(s1))
print("The R2_Score with the RF regressor is: "+str(s2))
# Out:
# The MAE with the RF regressor is: 1548254.935952381
# The MsE with the RF regressor is: 4285626378895.6367
# The R2_Score with the RF regressor is: -0.09452803102954532

# %% [markdown]
# ## K-Neighbors Regressor

# %%
knn=KNeighborsRegressor()
knn=knn.fit(X_train,y_train)

# %%
pred = knn.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the KNN regressor is: "+str(s))
print("The MsE with the KNN regressor is: "+str(s1))
print("The R2_Score with the KNN regressor is: "+str(s2))
# Out:
# The MAE with the KNN regressor is: 1700066.1
# The MsE with the KNN regressor is: 5088333616521.561
# The R2_Score with the KNN regressor is: -0.2995355362610843

# %% [markdown]
# ## XGB Regressor

# %%
xgb=XGBRegressor()
xgb=xgb.fit(X_train,y_train)
# Out:
# [07:28:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
pred = xgb.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the XGB regressor is: "+str(s))
print("The MsE with the XGB regressor is: "+str(s1))
print("The R2_Score with the XGB regressor is: "+str(s2))
# Out:
# The MAE with the XGB regressor is: 1642730.9791666667
# The MsE with the XGB regressor is: 5256036334594.464
# The R2_Score with the XGB regressor is: -0.34236599080433305

# %% [markdown]
# From all the models, RFregressor gave the minimum error, So thats the best model and should be chosen as the final model.
